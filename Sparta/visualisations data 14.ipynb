# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.random.randn(100)
data
# Out:
# array([ 0.15214112,  0.78132592, -0.52491433, -0.62788743,  0.42766293,
#        -1.04323853,  2.21626519,  0.80753537,  0.3012433 , -2.58252904,
#         1.21641147,  0.37233689,  0.00902847,  1.65080746,  1.32816356,
#         0.78884631,  0.07563409, -1.58766146, -0.65724675,  0.57157435,
#         0.73276243,  0.67312012,  2.32812181, -0.00941111,  0.24497781,
#        -0.35603398, -0.25678817, -0.2908054 ,  0.45446306,  1.02059867,
#         0.14804281,  1.64885713,  0.98312259, -0.37905768,  0.3703449 ,
#        -0.05299627, -0.09625141,  1.13597841, -1.2088063 , -2.07382922,
#         0.55134838,  1.94506319,  1.72440017, -0.60405169, -0.2534155 ,
#         0.4727337 , -0.1179782 , -0.04127256, -1.18948723,  0.04499277,
#         0.35559616, -0.77057588, -1.50134865,  0.14431302,  1.22174076,
#         1.3293676 , -0.51585678,  0.9395482 ,  0.02580029, -0.46295139,
#        -0.44874767,  0.59366493, -0.52577453,  2.20303129, -0.39619892,
# ...

# %%
plt.hist(data, bins=2)
# Out:
# (array([36., 64.]),
#  array([-2.58252904, -0.12720362,  2.32812181]),
#  <a list of 2 Patch objects>)

# %%
data2 = np.random.randn(100)
data2
# Out:
# array([-5.18522852e-01, -6.70003806e-01, -1.10375021e+00, -8.05489628e-01,
#        -1.16693648e+00, -1.86000547e-01,  7.80210389e-01,  7.20309187e-01,
#         1.76995855e-01, -8.27474052e-01, -7.43395749e-01, -3.93273155e-02,
#         4.69531934e-01,  1.07777519e+00,  1.51768342e-01, -5.47712548e-01,
#        -2.15124577e-01, -9.73862088e-01, -4.36877790e-01, -8.21039636e-01,
#         1.10004218e+00, -1.28321557e+00,  1.24975966e-01, -1.04480474e+00,
#        -2.72238906e-01, -5.01588538e-01, -9.80289963e-01, -8.94066695e-01,
#        -5.59900809e-01, -1.12609807e+00, -7.25066156e-01,  1.36242709e+00,
#        -1.37341562e+00,  7.97181500e-01, -3.00919094e-01,  1.91697102e+00,
#        -6.87258669e-01,  2.97948129e-01, -4.17854018e-01,  2.28103671e-03,
#         8.42650339e-01, -4.91256023e-01, -1.55638085e+00, -6.03492767e-02,
#         1.15693320e+00,  9.68565041e-02, -7.13579426e-01, -1.57262412e-01,
# ...

# %%
plt.hist(data2, bins=15, color='peachpuff')
# Out:
# (array([ 2.,  2.,  6., 13., 17., 16., 12.,  7., 12.,  7.,  3.,  0.,  2.,
#          0.,  1.]),
#  array([-2.2374562 , -1.89306283, -1.54866945, -1.20427608, -0.85988271,
#         -0.51548933, -0.17109596,  0.17329741,  0.51769079,  0.86208416,
#          1.20647753,  1.55087091,  1.89526428,  2.23965765,  2.58405103,
#          2.9284444 ]),
#  <a list of 15 Patch objects>)

# %%
plt.hist(data, color='teal', alpha=0.5, density = True)
plt.hist(data2, color = 'chartreuse', alpha=0.5, density=True)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0641c88a858a> in <module>
#       1 plt.hist(data, color='teal', alpha=0.5, density = True)
#       2 plt.hist(data2, color = 'chartreuse', alpha=0.5, density=True)
# ----> 3 plot.show()
#
# NameError: name 'plot' is not defined

# %%
import seaborn as sns

# %%
sns.distplot(data)

# %%
data1 = np.random.randn(1000)
data2 = np.random.poisson(1000, size=1000)

sns.jointplot(data1, data2, color='hotpink')

# %%
iris = pd.read_csv('~\\Downloads\\iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.jointplot(iris['sepal_width'], iris['sepal_length'],
             color = 'hotpink', kind='kde')
#kde is the kernel density estimate

# %%
sns.jointplot(data=iris, x='petal_length', y='petal_width', 
              kind='kde')

# %%
sns.pairplot(iris, hue='species')

# %%
sns.scatterplot(data=iris, x='petal_length', y='petal_width',
               hue = 'species')

# %%
sns.lmplot(data=iris, x='petal_length', y='petal_width')

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
fp = flights.pivot('year', 'month', 'passengers')

# %%
fp.head()
# Out:
# month  January  February  March  April  May  June  July  August  September  \
# year
# 1949       112       118    132    129  121   135   148     148        136
# 1950       115       126    141    135  125   149   170     170        158
# 1951       145       150    178    163  172   178   199     199        184
# 1952       171       180    193    181  183   218   230     242        209
# 1953       196       196    236    235  229   243   264     272        237
#
# month  October  November  December
# year
# 1949       119       104       118
# 1950       133       114       140
# 1951       162       146       166
# 1952       191       172       194
# 1953       211       180       201

# %%
sns.heatmap(fp, annot=True, fmt='d')

# %%
sns.jointplot(data=flights, x='year', y='passengers',
               kind = 'kde', color='red')
